# %% [markdown]
# ## Introduction to plotting
#
# ## Python package
#
# - `matplotlib`: all plot is pandas
# - `seaborn`: focus on statistical visualization
# - `bokeh`: to create interactive visualization for the internet
# - `plotly`

# %% [markdown]
# ### Matplotlib
# main submodule is `pyplot` which will give different function to work with different plot elements

# %% [markdown]
# ### create a plot
# - import the necessary packages
# - import or create data
# - call the approriate plotting

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# dummy data

x= [1,2,4,2,4,7,8,9]
y= [4,5,6,5,6,7,8,30]

# %%
# default is line plot
plt.plot(x,y)

# %% [markdown]
# ### test data
# get the data from
# `icarus.cs.weber.edu/~hvalle/cs4580/data/plottingDemo01.zip`

# %%
hw_df = pd.read_csv('../data/hw.csv')

hw_df.head()
# Out:
#    Index   Height(Inches)"   "Weight(Pounds)"
# 0      1             65.78             112.99
# 1      2             71.52             136.49
# 2      3             69.40             153.03
# 3      4             68.22             142.34
# 4      5             67.79             144.30

# %%
hw_df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## common plots
# - Line
# - Scatter
# - Bar
# - Histograms
# - Area

# %%
y =  [45,49,54,38,41]
plt.plot(y)

# %%
home_df = pd.read_csv('../data/homes.csv')
home_df.head()
# Out:
#    Sell  List  Living  Rooms  Beds  Baths  Age  Acres  Taxes
# 0   142   160      28     10     5      3   60   0.28   3167
# 1   175   180      18      8     4      1   12   0.43   4033
# 2   129   132      13      6     3      1   41   0.33   1471
# 3   138   140      17      7     3      1   22   0.46   3204
# 4   232   240      25      8     4      3    5   2.05   3613

# %%
home_df.plot()
# Out:
# <Axes: >

# %%
home_df.plot(x='List',y='Rooms', marker='o',markerfacecolor='r')
# Out:
# <Axes: xlabel='List'>

# %%
cities_df = pd.read_csv('../data/cities.csv')
cities_df.head()
# Out:
#         City  Year  Population
# 0  Charlotte  2015      825668
# 1  Charlotte  2016      843117
# 2  Charlotte  2017      860002
# 3  Charlotte  2018      872514
# 4  Charlotte  2019      885708

# %%
cities_2019_df = cities_df[cities_df['Year']==2019]
cities_2019_df.head()
# Out:
#              City  Year  Population
# 4       Charlotte  2019      885708
# 9   San Francisco  2019      881549
# 14   Indianapolis  2019      876384
# 19        Seattle  2019      753675
# 24         Denver  2019      727211

# %%
cities_2019_df.plot(kind='bar',x='City',y='Population', title='Population of City 2019', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Population of City 2019'}, xlabel='City'>

# %%
cities_2019_df.plot(kind='barh',x='City',y='Population', title='Population of City 2019', legend=False,figsize=(10,6))
# Out:
# <Axes: title={'center': 'Population of City 2019'}, ylabel='City'>

# %%
houses_df = pd.read_csv('../data/homes.csv')

houses_df.head()
# Out:
#    Sell  List  Living  Rooms  Beds  Baths  Age  Acres  Taxes
# 0   142   160      28     10     5      3   60   0.28   3167
# 1   175   180      18      8     4      1   12   0.43   4033
# 2   129   132      13      6     3      1   41   0.33   1471
# 3   138   140      17      7     3      1   22   0.46   3204
# 4   232   240      25      8     4      3    5   2.05   3613

# %%
houses_df.plot(kind='scatter',x='List',y='Rooms')
# Out:
# <Axes: xlabel='List', ylabel='Rooms'>

# %%
houses_df[houses_df['Age']<50].plot(kind='scatter',x='Age',y='List')
# Out:
# <Axes: xlabel='Age', ylabel='List'>

# %%
houses_plot_df = houses_df[houses_df['Age']<50]
houses_plot_df = houses_plot_df[houses_plot_df['List']<350]

houses_plot_df.plot(kind='scatter', x='Age', y='List')
# Out:
# <Axes: xlabel='Age', ylabel='List'>

# %%
houses_plot_df.head()
# Out:
#    Sell  List  Living  Rooms  Beds  Baths  Age  Acres  Taxes
# 1   175   180      18      8     4      1   12   0.43   4033
# 2   129   132      13      6     3      1   41   0.33   1471
# 3   138   140      17      7     3      1   22   0.46   3204
# 4   232   240      25      8     4      3    5   2.05   3613
# 5   135   140      18      7     4      3    9   0.57   3028

# %%
houses_plot_df['Acres'].plot(kind='hist',title='Acre Dis')
# Out:
# <Axes: title={'center': 'Acre Dis'}, ylabel='Frequency'>

# %%
enrollments_df = pd.read_csv('../data/enrollment.csv')

enrollments_df.head()
# Out:
#    Year      Class  Enrollment
# 0  2018   Freshman        1500
# 1  2018  Sophomore        1400
# 2  2018     Junior        1300
# 3  2018     Senior        1200
# 4  2019   Freshman        1600

# %%
enrollments_df.plot(kind='area',x='Year')
# Out:
# <Axes: xlabel='Year'>

# %%
pivot_df = enrollments_df.pivot(index='Year',columns='Class', values='Enrollment')

pivot_df.head()
# Out:
# Class  Freshman  Junior  Senior  Sophomore
# Year
# 2018       1500    1300    1200       1400
# 2019       1600    1200    1100       1500
# 2020       1650    1100    1080       1320
# 2021       1400    1100    1150       1390
# 2022       1720    1080     990       1300

# %%
pivot_df.plot(kind='area')
# Out:
# <Axes: xlabel='Year'>

# %%
pivot_df.plot(kind='area',stacked=False)
# Out:
# <Axes: xlabel='Year'>
